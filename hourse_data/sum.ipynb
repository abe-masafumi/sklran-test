# %%
import pandas as pd

# %%
pd.set_option('display.max_rows',5)
pd.options.display.width = 200
pd.options.display.column_space = 100

# %%
results1 = pd.read_pickle("add.cleaned.pickle")
results2 = pd.read_pickle("cleaned.pickle")

# %%
results1
# Out:
#               着順  枠  馬番         馬名    斤量    騎手    人気  性  齢   体重  体重変化
# 202101020401   1  2   2  イエヴァンポルッカ  54.0    坂井   3.0  牡  2  470     2
# 202101020401   2  6   8  テイエムケントオー  52.0  △秋山稔   9.0  牡  2  446    -4
# ...           .. ..  ..        ...   ...   ...   ... .. ..  ...   ...
# 202101020401  12  3   3     アポロリヤム  54.0   横山武   2.0  牡  2  446     0
# 202101020401  13  5   7     クリエースト  54.0    加藤  12.0  牝  2  450     4
#
# [13 rows x 11 columns]

# %%
results2
# Out:
#               着順  枠  馬番         馬名    斤量    騎手    人気  性  齢   体重  体重変化
# 202101010101   1  5   9  ディーバサンライズ  52.0  △秋山稔   7.0  牝  3  474   -22
# 202101010101   2  3   6      バンベルク  56.0   横山和   2.0  牡  3  470    -2
# ...           .. ..  ..        ...   ...   ...   ... .. ..  ...   ...
# 202104030402  17  3   5     ピンクパフェ  54.0    嘉藤  18.0  牝  2  414    -2
# 202104030402  18  2   4    ユアマイホープ  51.0  ▲小林脩  14.0  牡  2  466    -6
#
# [847 rows x 11 columns]

# %%
pd.set_option('display.max_rows',None)

df = pd.concat(objs=[results1, results2])
# df3

# %%
df.to_pickle("df.pickle")
