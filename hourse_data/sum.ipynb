# %%
import pandas as pd

# %%
pd.set_option('display.max_rows',5)
pd.options.display.width = 200
pd.options.display.column_space = 100

# %%
results1 = pd.read_pickle("df.pickle")
# results1 = pd.read_pickle("cleaned.pickle")
results2 = pd.read_pickle("add.cleaned.pickle")

# %%
len(results1)
# Out:
# 1958

# %%
results1
# Out:
#               着順  枠  馬番         馬名    斤量    騎手    人気  性  齢   体重  体重変化
# 202101010101   1  5   9  ディーバサンライズ  52.0  △秋山稔   7.0  牝  3  474   -22
# 202101010101   2  3   6      バンベルク  56.0   横山和   2.0  牡  3  470    -2
# ...           .. ..  ..        ...   ...   ...   ... .. ..  ...   ...
# 202110030302  15  7  13    タケノサイコウ  54.0   鮫島駿  15.0  牡  2  456     2
# 202110030302  16  7  14  カシノファボリート  54.0    森裕  10.0  牝  2  468    -4
#
# [1958 rows x 11 columns]

# %%
len(results2)
# Out:
# 458

# %%
results2
# Out:
#               着順    枠  馬番        馬名    斤量   騎手    人気  性  齢   体重  体重変化
# 202104040101   1  1.0   1  ベストリーガード  54.0  木幡巧   5.0  牡  2  454     0
# 202104040101   2  5.0   9  セイウンハルカニ  54.0   丸山   2.0  牡  2  460     8
# ...           ..  ...  ..       ...   ...  ...   ... .. ..  ...   ...
# 202110040302  15  7.0  13      ギレルモ  56.0  岩田望  10.0  牡  3  490     0
# 202110040302  16  7.0  14    クリノミカサ  54.0   藤懸  16.0  牝  3  450    -4
#
# [458 rows x 11 columns]

# %%
pd.set_option('display.max_rows',None)

df = pd.concat(objs=[results1, results2])
# df

# %%
len(df)
# Out:
# 2416

# %%
df.to_pickle("df.pickle")

# %%
pd.read_pickle("df.pickle")
# Out:
#               着順    枠  馬番         馬名    斤量    騎手    人気  性   齢   体重  体重変化
# 202101010101   1  5.0   9  ディーバサンライズ  52.0  △秋山稔   7.0  牝   3  474   -22
# 202101010101   2  3.0   6      バンベルク  56.0   横山和   2.0  牡   3  470    -2
# 202101010101   3  7.0  14      リツィタル  54.0    大野  14.0  牝   3  394     2
# 202101010101   4  5.0  10  クレマチステソーロ  54.0   鮫島駿   5.0  牝   3  468     2
# 202101010101   5  3.0   5  ペイシャケイティー  54.0   古川吉   4.0  牝   3  456     8
# 202101010101   6  1.0   2       セリシア  54.0    武豊   1.0  牝   3  456     4
# 202101010101   7  4.0   7      デクラーク  56.0   横山武   3.0  牡   3  444     2
# 202101010101   8  6.0  11    プレジャジンク  54.0   吉田隼   8.0  牝   3  452    12
# 202101010101   9  7.0  13     メルティング  54.0    団野   9.0  牝   3  416     0
# 202101010101  10  2.0   3    リトルロータス  52.0   △山田  16.0  牝   3  388   -20
# 202101010101  11  4.0   8    ニースバローズ  51.0  ▲横山琉  15.0  牝   3  402     6
# 202101010101  12  2.0   4    マイネルニゲラ  56.0    丹内  11.0  牡   3  498    -4
# ...
