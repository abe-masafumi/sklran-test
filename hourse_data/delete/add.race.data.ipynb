# %%
import pandas as pd
from tqdm import tqdm
import time

# %%
# url = "https://race.netkeiba.com/race/result.html?race_id=202105010101"
# pd.read_html(url)[0]

# %%
pd.set_option('display.max_rows',20)
pd.options.display.width = 200
pd.options.display.column_space = 100

# %%
race_result = pd.read_pickle("df.pickle")
# race_result = pd.read_pickle("cleaned.pickle")
print(type(race_result.index[0]))

"202101010101" in race_result.index
# Out:
# <class 'str'>
# True

# %%
race_id_lists = []

for 年 in range(2021,2022):
  for 競馬場 in range(1,11): # 1,11
    for 回 in range(1,4): # 1,11
      for 回目 in range(1,5): # 1,11
        for レース回 in range(1,13): # 1,13
          race_id = f"{年}{str(競馬場).zfill(2)}{str(回).zfill(2)}{str(回目).zfill(2)}{str(レース回).zfill(2)}"
          race_id_lists.append(race_id)
# print(race_id_lists)

# 実行時間 72分
def scrape_race_results(race_id_lists,par_race_results={}):
  race_result_dict = par_race_results
  for _race_id in tqdm(race_id_lists):
    if _race_id in race_result.index:
      continue
    try:
      url = "https://race.netkeiba.com/race/result.html?race_id=" + _race_id
      race_result_dict[_race_id] = pd.read_html(url)[0]
      # print(race_result_dict[race_id])
      time.sleep(1)
    except UnicodeDecodeError as e:
      # print(e)
      # print(f"レースID: {race_id} のデータはありません")
      continue
    except KeyboardInterrupt:
      break
    except TimeoutError:
      break
  return race_result_dict
  
add_race_result = (race_id_lists)
# Out:
# 100%|██████████| 1440/1440 [24:45<00:00,  1.03s/it]

# %%
len(add_race_result)
# Out:
# 966

# %%
# add_race_result

# %%
for key in add_race_result.keys():
  add_race_result[key].index = [key] * len(add_race_result[key])
print(type(add_race_result))
# Out:
# <class 'dict'>

# %%
results = pd.concat([add_race_result[key] for key in add_race_result.keys()],sort=False)
print(type(results))
results
# Out:
# <class 'pandas.core.frame.DataFrame'>
#              着順  枠  馬番         馬名  性齢    斤量    騎手     タイム     着差   人気  ... コーナー通過順     厩舎   馬体重(増減) Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 202101010103  1  8  11   エレファンティネ  牝3  54.0   鮫島駿  1:00.1    NaN   11  ...     2-3  美浦斎藤誠   430(-8)         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 202101010103  2  5   5   ファイヤービート  牡3  54.0   △泉谷  1:00.3  1.1/4    4  ...     6-6   栗東茶木   450(+6)         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 202101010103  3  8  12  ハクサンタマテバコ  牝3  54.0    丹内  1:00.5  1.1/4    2  ...     1-1   美浦武藤   438(-8)         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 202101010103  4  4   4    デイジームーン  牝3  54.0    菱田  1:00.6     クビ    7  ...     7-7    栗東谷   430(-8)         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 202101010103  5  1   1    ブリエヴェール  牡3  53.0  ▲小林凌  1:00.6    アタマ    6  ...    9-10   美浦小笠   460(-2)         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# ...          .. ..  ..        ...  ..   ...   ...     ...    ...  ...  ...     ...    ...       ...         ...         ...         ...         ...         ...         ...         ...
# 202110030412  4  1   1   メイショウソウビ  セ7  57.0     幸  0:58.5      1  5.0  ...     6-3  栗東飯田祐   476(-6)         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 202110030412  5  4   4  オンリーワンスター  牝8  55.0   和田翼  0:58.5     クビ  7.0  ...     4-5   栗東渡辺  464(-10)         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 202110030412  6  2   2    マカオンブラン  牡4  57.0   和田竜  0:58.5    アタマ  4.0  ...     2-2   栗東今野  484(-12)         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 202110030412  7  7   7   ブラッディムーン  牝5  55.0    松若  0:58.7    3/4  3.0  ...     4-5   栗東上村  460(-10)         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 202110030412  8  8   8     ミコブラック  牝3  52.0   鮫島駿  0:58.9  1.1/4  NaN  ...     NaN    NaN       NaN         NaN         NaN         NaN       栗東安田隆     468(+4)         NaN         NaN
#
# [13349 rows x 22 columns]

# %%
results.to_pickle("add.results.pickle")
